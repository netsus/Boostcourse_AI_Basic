# %% [markdown]
# ## built-in Exception
# ![image.png](attachment:image.png)

# %% [markdown]
# ## raise
# : 필요에 따라 강제로 Exception 발생
#
# <img src=https://blog.kakaocdn.net/dn/P1sfG/btrF76G6KLC/TXKlGwzDKqXT9m05tbOR2k/img.png width=1000>

# %%
a=input()
for d in a:
    if d not in "0123456789":
        raise ValueError("숫자값이 아닙니다.")
# Out:
# a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-d551683c3d78> in <module>
#       2 for d in a:
#       3     if d not in "0123456789":
# ----> 4         raise ValueError("숫자값이 아닙니다.")
#
# ValueError: 숫자값이 아닙니다.

# %% [markdown]
# ## assert
# : 특정 조건에 False -> 에러 발생

# %%
def get_bi_num(num: int):
    assert isinstance(num, int)
    return bin(num)

# %%
print(get_bi_num(10))
# Out:
# 0b1010

# %%
print(get_bi_num('a'))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-755a781604e8> in <module>
# ----> 1 print(get_bi_num('a'))
#
# <ipython-input-7-2b337a065286> in get_bi_num(num)
#       1 def get_bi_num(num: int):
# ----> 2     assert isinstance(num, int)
#       3     return bin(num)
#
# AssertionError:
