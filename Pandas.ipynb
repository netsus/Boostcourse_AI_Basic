# %%
from pydataset import data
import pandas as pd

# %%
df = data('titanic')
df.head(2)
# Out:
#        class     age  sex survived
# 1  1st class  adults  man      yes
# 2  1st class  adults  man      yes

# %%
df['survived']=df.survived.replace({'yes':1,'no':0})
df.head(2)
# Out:
#        class     age  sex  survived
# 1  1st class  adults  man         1
# 2  1st class  adults  man         1

# %% [markdown]
# ### Groupby - DataFrame이 split 된다.
# <br>
# <div>
#     <img src=attachment:image.png width=800>
# </div>
# <br>

# %%
pd.DataFrame(df.groupby('class'))[1][0].head(2)
# Out:
#        class     age  sex  survived
# 1  1st class  adults  man         1
# 2  1st class  adults  man         1

# %%
pd.DataFrame(df.groupby('class'))[1][1].head(2)
# Out:
#          class     age  sex  survived
# 326  2nd class  adults  man         1
# 327  2nd class  adults  man         1

# %%
pd.DataFrame(df.groupby('class'))[1][2].head(2)
# Out:
#          class     age  sex  survived
# 611  3rd class  adults  man         1
# 612  3rd class  adults  man         1
